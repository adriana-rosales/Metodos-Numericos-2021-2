# %% [markdown]
# <a href="https://colab.research.google.com/github/adriana-rosales/Metodos-Numericos-2021-2/blob/main/Wegstein.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# `NOTAS:`
#
# $$
# ln(x)⇒log(x)
# $$
# $$
# sen(x)⇒sin(x)⇒np.sin(x)
# $$
#
# $$
# ⇒np.cos(x)
# $$
#
# $$
# \pi⇒np.pi=math.pi
# $$
#
# $$
# e^{x}⇒np.exp(x)
# $$

# %% [markdown]
# #GENERAL **➭USAR LISTING 2. ➭SUPONER x0.  ➭A MANO DESPEJAR x**
#
#
# -Es una variación de *punto fijo*.
#
# -**Suponer un x₀**
#
# -Se itera hasta la presición deseada.
#
#
# 1. `Función`
# $$
# f(x)=dato
# $$
# 2. `Punto inicial`
# $$
# x_0=dato
# $$
# 3. `*Orden`
# $$
# 10^{orden}
# $$
# 4.   `Igualar f(x)=0, despejar x`
# $$
# x=
# $$
# 5.   `Evaluar Función 1 en x₀ 2`
# $$
# f(x)|_{x_0}
# $$
#
# $$
# g(x_0)=
# $$
# 6. * `x₁`
# $$
# x_1=g(x_0)=
# $$
# 7.  * `Evaluar Función 1 en x₁ 5`
# $$
# g(x_1)=
# $$
# 8. * `x₂`
# $$
# x_2=g(x_1)=
# $$
# 9.  * `Evaluar Función 1 en x₂ 7`
# $$
# g(x_2)=
# $$
# 10. `i=1 con DATOS *`
# $$
# i=1
# $$
# $$
# x_3=\frac{x_1g(x_2)-x_2g(x_1)}{x_1-g(x_1)-x_2+g(x_2)}
# $$
# 11. `i=2,i=3... CON DATOS OBTENIDOS DE LA TABLA DE ITERACIONES`
# $$
# i=2,x_3
# $$
# $$
# i=3,x_4
# $$
# **Resultado:**
#
# La raíz aproximada es ... con una precisión del orden 10^, hasta la *n* iteración
#
# $$
# |x_n-x_{n-1}|<1x10^{orden}
# $$
#
# \begin{array}{|c|c|c|c|}
# \hline
# Iteraciones&x_i\\
# \hline
# 1&-\\
# \hline
# \end{array}
#
#
# ##Editar listing:
#
# * 7: `tol=`
# * 30: `f(x) DESPEJADA ⇒x `
# * 34: `EDIT x0`
# * 39: `EDIT Rango de la gráfica`

# %% [markdown]
# #1: Libro

# %%
#Import Biblioteca math
import numpy as np
import matplotlib.pyplot as plt
import math
import cmath

def wegstein(g,x0,imax=100,tol=1e-8):
    cumple=False
    print('{:^10s} {:^10s} {:^10s} {:^10s} {:^10s} {:^10s}'.\
          format('x1','x2','x3','g(x1)','g(x2)','g(x3)'))
    x1=g(x0)
    x2=g(x1)
    k=0
    while (not cumple and k<imax):
      x3=(x1*g(x2)-x2*g(x1))/(x1-g(x1)-x2+g(x2))
      print('{:10.5f} {:10.5f} {:10.5f} {:10.5f} {:10.5f} {:10.5f}'.\
            format(x1,x2,x3,g(x1),g(x2),g(x3)))
      x1=x2
      x2=x3
      cumple=abs(x2-g(x2))<=tol

      k+=1
    if k<imax:
      return x3
    else:
      raise ValueError ('La función no converge')

# Función a evaluar
def g(v):
    n=2
    R=0.082
    a=3.592
    b=0.04267
    T=300
    P=10
    return n*R*T/(P+n**2*a/v**2)+n*b

def main():
    # Valores iniciales
    x0=2
    # Call
    raiz=wegstein(g,x0)
    print('f({:e})={:e}'.format(raiz,g(raiz)-raiz))

    x=np.linspace(0.01,6,100)
    y=g(x)-x

    fig = plt.figure()
    plt.plot(x,y,label='$f(x)$')

    plt.plot(x,x,':',label='$x$')
    plt.plot(x,g(x),':',label='$g(x)$')
    plt.plot(np.array([raiz,raiz]),np.array([0,g(raiz)]),'-.')

    plt.title('Volumen de $C0_2$')
    plt.scatter(raiz,g(raiz)-raiz)
    plt.text(raiz,g(raiz)-raiz,'Raiz'+str(raiz),color='red')
    plt.legend()
    plt.grid()
    plt.show()
    fig.savefig("wegstein.pdf", bbox_inches='tight')

if __name__ == "__main__": main()
# Out:
#     x1         x2         x3       g(x1)      g(x2)      g(x3)
#    3.70512    4.53919    4.71533    4.53919    4.68462    4.70670
#    4.53919    4.71533    4.70547    4.68462    4.70670    4.70553
#    4.71533    4.70547    4.70554    4.70670    4.70553    4.70554
#    4.70547    4.70554    4.70554    4.70553    4.70554    4.70554
# f(4.705535e+00)=-3.654410e-11

# %% [markdown]
# #2:
#
# Aproximar una raíz de la siguiente función, con una precisión de 10⁻³. Punto inicial:
# $$
# x_0=0
# $$
# $$
# f(x)=e^{-x}-x
# $$
#
# 1. `Función`
# $$
# f(x)=e^{-x}-x
# $$
# 2. **SUPONER** *`Punto inicial`
# $$
# x_0=0
# $$
# 3. `*Orden`
# $$
# 10^{-3}
# $$
# 4.   `Igualar f(x)=0, despejar x`
# $$
# x=e^{-x}
# $$
# 5. `Evaluar Función 1 en x₀ 2`
# $$
# f(x)|_{x_0}
# $$
#
# $$
# g(x_0)=1
# $$
# 6.   *`x₁`
# $$
# x_1=g(x_0)=1
# $$
# 7.  * `Evaluar Función 1 en x₁ 5`
# $$
# g(x_1)=0.3678 ⇒python
# $$
# 8. * `x₂`
# $$
# x_2=g(x_1)=0.3678
# $$
# 9.  * `Evaluar Función 1 en x₂ 7`
# $$
# g(x_2)=0.69220
# $$
# 10. `i=1 con DATOS *`
# $$
# i=1
# $$
# $$
# x_3=\frac{x_1g(x_2)-x_2g(x_1)}{x_1-g(x_1)-x_2+g(x_2)}
# $$
# 11. `i=2,i=3... CON DATOS OBTENIDOS DE LA TABLA DE ITERACIONES`
# $$
# i=2,x_3
# $$
# $$
# i=3,x_4
# $$
# **Resultado:**
#
# La raíz aproximada es ... con una precisión del orden 10^, hasta la *n* iteración
#
# $$
# |x_n-x_{n-1}|<1x10^{orden}
# $$
#
# \begin{array}{|c|c|c|c|}
# \hline
# Iteraciones&x_i\\
# \hline
# 1&-\\
# \hline
# \end{array}
#
#
# ##Editar listing:
#
# * 7: `tol=`
# * 30: `f(x) DESPEJADA ⇒x `
# * 34: `EDIT x0`
# * 39: `EDIT Rango de la gráfica`

# %%
#Import Biblioteca math
import numpy as np
import matplotlib.pyplot as plt
import math
import cmath

def wegstein(g,x0,imax=100,tol=1e-8):         #tol=
    cumple=False
    print('{:^10s} {:^10s} {:^10s} {:^10s} {:^10s} {:^10s}'.\
          format('x1','x2','x3','g(x1)','g(x2)','g(x3)'))
    x1=g(x0)
    x2=g(x1)
    k=0
    while (not cumple and k<imax):
      x3=(x1*g(x2)-x2*g(x1))/(x1-g(x1)-x2+g(x2))
      print('{:10.5f} {:10.5f} {:10.5f} {:10.5f} {:10.5f} {:10.5f}'.\
            format(x1,x2,x3,g(x1),g(x2),g(x3)))
      x1=x2
      x2=x3
      cumple=abs(x2-g(x2))<=tol

      k+=1
    if k<imax:
      return x3
    else:
      raise ValueError ('La función no converge')

# Función a evaluar
def g(x):
    return np.exp(-x)                        #f(x) DESPEJADA ⇒x

def main():
    # Valores iniciales
    x0=0                                     #EDIT x0
    # Call
    raiz=wegstein(g,x0)
    print('f({:e})={:e}'.format(raiz,g(raiz)-raiz))

    x=np.linspace(-5,5,100)                  #EDIT Rango de gráfica
    y=g(x)-x

    fig = plt.figure()
    plt.plot(x,y,label='$f(x)$')

    plt.plot(x,x,':',label='$x$')
    plt.plot(x,g(x),':',label='$g(x)$')
    plt.plot(np.array([raiz,raiz]),np.array([0,g(raiz)]),'-.')

    plt.title('Método de Wegstein')
    plt.scatter(raiz,g(raiz)-raiz)
    plt.text(raiz,g(raiz)-raiz,'Raíz aproximada='+str(raiz),color='red')
    plt.legend()
    plt.grid()
    plt.show()
    fig.savefig("wegstein.pdf", bbox_inches='tight')

if __name__ == "__main__": main()

#Raíces aproximadas x3

#RESPUESTA:

#Raíz aprox: x3=0.56714
#en i=3 
#con tol=1e-4
# Out:
#     x1         x2         x3       g(x1)      g(x2)      g(x3)
#    1.00000    0.36788    0.58223    0.36788    0.69220    0.55865
#    0.36788    0.58223    0.56770    0.69220    0.55865    0.56683
#    0.58223    0.56770    0.56714    0.55865    0.56683    0.56714
#    0.56770    0.56714    0.56714    0.56683    0.56714    0.56714
# f(5.671433e-01)=-2.412872e-10
