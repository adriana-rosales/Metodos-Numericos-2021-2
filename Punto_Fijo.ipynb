# %% [markdown]
# <a href="https://colab.research.google.com/github/adriana-rosales/Metodos-Numericos-2021-2/blob/main/Punto_Fijo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# `NOTAS:`
#
# $$
# ln(x)⇒log(x)
# $$
# $$
# sen(x)⇒sin(x)⇒np.sin(x)
# $$
#
# $$
# ⇒np.cos(x)
# $$
#
# $$
# \pi⇒np.pi=math.pi
# $$
#
# $$
# e^{x}⇒np.exp(x)
# $$

# %% [markdown]
# #GENERAL **➭USAR LISTING 3. ➭DESPEJAR x A MANO. ➭PROPONER x0.**
#
# #3:
#
#
# 1. `Función`
# $$
# f(x)=dato
# $$
#
# 2. `*Orden`
# $$
# 10^{orden}
# $$
#
# 3.   `Despejar x`
#
# $$
# ⇒x=
# $$
# $$
# x=g(x)
# $$
# 4.   `Proponer un x0`
# $$
# x_0=
# $$
#
# 5. `x₁:`
#
# `Evaluar la Función g(x) 1 en x0 2`
#
# $$
# g(x_0)=
# $$
# $$
# g(x_0)=x_1
# $$
#
#
# 6. `x₁, x₂... CON DATOS OBTENIDOS DE LA TABLA DE ITERACIONES`
# $$
# g(x_1)=x_2
# $$
# $$
# g(x_2)=x_3
# $$
# $$
# g(x_3)=x_4
# $$
# $$
# g(x_4)=x_5
# $$
#
#
# **Resultado:**
#
# La raíz aproximada es ... con una precisión del orden 10^, hasta la *n* iteración
#
# $$
# |x_n-x_{n-1}|<1x10^{orden}
# $$
#
# \begin{array}{|c|c|c|c|}
# \hline
# Iteraciones&x_i\\
# \hline
# 1&-\\
# \hline
# \end{array}
#
#
# ##Editar listing:
#
# * 7: `tol=`
# * 26: `f(x) DESPEJADA ⇒x `
# * 30: `EDIT x0`
# * 35: `EDIT Rango de la gráfica`

# %% [markdown]
# #1: Libro

# %%
#Import Biblioteca math
import numpy as np
import matplotlib.pyplot as plt
import math
import cmath

def puntoFijo(g,x,imax=100,tol=1e-8):
    cumple=False
    print('{:^10s} {:^10s}'.\
          format('x','g(x)'))
    k=0
    while (not cumple and k<imax):
        print('{:10.5f}{:10.5f}'.\
              format(x,g(x)))
        x=g(x)
        cumple=abs(x-g(x))<=tol

        k+=1
    if k<imax:
        return x
    else:
        raise ValueError ('La función no converge')

# Función a evaluar
def g(v):
    n=2
    R=0.082
    a=3.592
    b=0.04267
    T=300
    P=10
    return n*R*T/(P+n**2*a/v**2)+n*b

def main():
    # Valores iniciales
    x0=2
    # Call
    raiz=puntoFijo(g,x0)
    print('f({:e})={:e}'.format(raiz,g(raiz)-raiz))

    x=np.linspace(0.01,6,100)
    y=g(x)-x

    fig=plt.figure()
    plt.plot(x,y,label='$f(x)$')

    plt.plot(x,x,':',label='$x$')
    plt.plot(x,g(x),':',label='$g(x)$')
    plt.plot(np.array([raiz,raiz]),np.array([0,g(raiz)]),'-.')

    plt.title('Método del Punto Fijo$')
    plt.scatter(raiz,g(raiz)-raiz)
    plt.text(raiz,g(raiz)-raiz,'Raiz'+str(raiz),color='red')
    plt.legend()
    plt.grid()
    plt.show()
    fig.savefig("puntoFijo.pdf", bbox_inches='tight')

if __name__ == "__main__": main()

# RESULTADO en ROJO
# Out:
#     x         g(x)
#    2.00000   3.70512
#    3.70512   4.53919
#    4.53919   4.68462
#    4.68462   4.70302
#    4.70302   4.70523
#    4.70523   4.70550
#    4.70550   4.70553
#    4.70553   4.70553
#    4.70553   4.70554
#    4.70554   4.70554
# f(4.705535e+00)=6.514502e-09

# %% [markdown]
# #2:
#
# Resolver f(x)=0 encontrando una raíz de la función:
# $$
# f(x)=e^{-2x}-x
# $$
#
#
#
# 1.   `Despejar x`
#
# $$
# x=e^{-2x}
# $$
# $$
# x=g(x)
# $$
# 2.   `Proponer un x0`
# $$
# x_0=0.75
# $$
# 3. `x₁:`
#
# `Evaluar la Función g(x) 1 en x0 2`
#
# $$
# g(x_0)=0.2231301601
# $$
# $$
# g(x_0)=x_1
# $$
#
# 4. `x₂,x₃... CON DATOS OBTENIDOS DE LA TABLA DE ITERACIONES`
# $$
# g(x_1)=x_2
# $$
# $$
# g(x_2)=x_3
# $$
# $$
# g(x_3)=x_4
# $$
# $$
# g(x_4)=x_5
# $$
#
#
# **Resultado:**
#
# La raíz aproximada es ... con una precisión del orden 10^, hasta la *n* iteración
#
# $$
# |x_n-x_{n-1}|<1x10^{orden}
# $$
#
# \begin{array}{|c|c|c|c|}
# \hline
# Iteraciones&x_i\\
# \hline
# 1&-\\
# \hline
# \end{array}
#
#
# ##Editar listing:
#
# * 7: `tol=`
# * 30: `f(x) DESPEJADA ⇒x `
# * 34: `EDIT x0`
# * 39: `EDIT Rango de la gráfica`

# %%
#Import Biblioteca math
import numpy as np
import matplotlib.pyplot as plt
import math
import cmath

def puntoFijo(g,x,imax=100,tol=1e-8):
    cumple=False
    print('{:^10s} {:^10s}'.\
          format('x','g(x)'))
    k=0
    while (not cumple and k<imax):
        print('{:10.5f}{:10.5f}'.\
              format(x,g(x)))
        x=g(x)
        cumple=abs(x-g(x))<=tol

        k+=1
    if k<imax:
        return x
    else:
        raise ValueError ('La función no converge')

# Función a evaluar
def g(x):
    return np.exp(-2*x)

def main():
    # Valores iniciales
    x0=0.75
    # Call
    raiz=puntoFijo(g,x0)
    print('f({:e})={:e}'.format(raiz,g(raiz)-raiz))

    x=np.linspace(-5,5,100)
    y=g(x)-x

    fig=plt.figure()
    plt.plot(x,y,label='$f(x)$')

    plt.plot(x,x,':',label='$x$')
    plt.plot(x,g(x),':',label='$g(x)$')
    plt.plot(np.array([raiz,raiz]),np.array([0,g(raiz)]),'-.')

    plt.title('Método del Punto Fijo$')
    plt.scatter(raiz,g(raiz)-raiz)
    plt.text(raiz,g(raiz)-raiz,'Raiz'+str(raiz),color='red')
    plt.legend()
    plt.grid()
    plt.show()
    fig.savefig("puntoFijo.pdf", bbox_inches='tight')

if __name__ == "__main__": main()

# RESULTADO en ROJO
# Out:
#     x         g(x)
#    0.75000   0.22313
#    0.22313   0.64002
#    0.64002   0.27803
#    0.27803   0.57347
#    0.57347   0.31761
#    0.31761   0.52982
#    0.52982   0.34658
#    0.34658   0.49999
#    0.49999   0.36788
#    0.36788   0.47914
#    0.47914   0.38355
#    0.38355   0.46435
#    0.46435   0.39506
#    0.39506   0.45379
#    0.45379   0.40350
#    0.40350   0.44619
#    0.44619   0.40968
#    0.40968   0.44072
#    0.44072   0.41419
#    0.41419   0.43676
#    0.43676   0.41748
#    0.41748   0.43389
#    0.43389   0.41988
#    0.41988   0.43181
#    0.43181   0.42163
#    0.42163   0.43030
#    0.43030   0.42290
#    0.42290   0.42921
#    0.42921   0.42383
#    0.42383   0.42842
#    0.42842   0.42451
#    0.42451   0.42784
#    0.42784   0.42500
#    0.42500   0.42742
#    0.42742   0.42535
#    0.42535   0.42711
#    0.42711   0.42561
#    0.42561   0.42689
#    0.42689   0.42580
#    0.42580   0.42673
#    0.42673   0.42594
#    0.42594   0.42661
# ...

# %% [markdown]
# #3:
#
#
# Resolver f(x)=0 encontrando una raíz de la función:
# $$
# f(x)=e^{-3x}-5x+2
# $$
#
#
# 1. `Función`
# $$
# f(x)=dato
# $$
#
# 2. `*Orden`
# $$
# 10^{-3}
# $$
#
# 3.   `Despejar x`
#
# $$
# 5x=e^{-3x}+2
# $$
#
# $$
# ⇒x=\frac{e^{-3x}+2}{5}
# $$
# $$
# x=g(x)
# $$
# 4.   `Proponer un x0`
# $$
# x_0=2
# $$
#
# 5. `x₁:`
#
# `Evaluar la Función g(x) 3 en x0 4`
#
# $$
# g(x_0)=0.40049575043533325⇒python
# $$
# $$
# g(x_0)=x_1
# $$
#
#
# 6. `x₁, x₂... CON DATOS OBTENIDOS DE LA TABLA DE ITERACIONES`
# $$
# g(x_1)=x_2
# $$
# $$
# g(x_2)=x_3
# $$
# $$
# g(x_3)=x_4
# $$
# $$
# g(x_4)=x_5
# $$
#
# **Resultado**
#
# La raíz aproximada es 0.4518024703 con una precisión del orden 10⁻³.

# %%
#Import Biblioteca math
import numpy as np
import matplotlib.pyplot as plt
import math
import cmath

def puntoFijo(g,x,imax=100,tol=1e-3):              #tol=
    cumple=False
    print('{:^10s} {:^10s}'.\
          format('x','g(x)'))
    k=0
    while (not cumple and k<imax):
        print('{:10.10f}{:10.10f}'.\
              format(x,g(x)))
        x=g(x)
        cumple=abs(x-g(x))<=tol

        k+=1
    if k<imax:
        return x
    else:
        raise ValueError ('La función no converge')

# Función a evaluar
def g(x):
    return (np.exp(-3*x)+2)/5                      #EDIT f(x)

def main():
    # Valores iniciales
    x0=2                                           #EDIT x0
    # Call
    raiz=puntoFijo(g,x0)
    print('f({:e})={:e}'.format(raiz,g(raiz)-raiz))

    x=np.linspace(-5,5,100)                        #Rango-gráfica
    y=g(x)-x

    fig=plt.figure()
    plt.plot(x,y,label='$f(x)$')

    plt.plot(x,x,':',label='$x$')
    plt.plot(x,g(x),':',label='$g(x)$')
    plt.plot(np.array([raiz,raiz]),np.array([0,g(raiz)]),'-.')

    plt.title('Método del Punto Fijo$')
    plt.scatter(raiz,g(raiz)-raiz)
    plt.text(raiz,g(raiz)-raiz,'Raiz aproximada='+str(raiz),color='red')
    plt.legend()
    plt.grid()
    plt.show()
    fig.savefig("puntoFijo.pdf", bbox_inches='tight')

if __name__ == "__main__": main()

# RESULTADO en ROJO
# Out:
#     x         g(x)
# 2.00000000000.4004957504
# 0.40049575040.4601493187
# 0.46014931870.4502931764
# 0.45029317640.4518024703
# f(4.518025e-01)=-2.340252e-04

# %% [markdown]
# #4: λ (ej. 2)
#
# Resolver f(x)=0 encontrando una raíz de la función:
# $$
# f(x)=e^{-2x}-x
# $$
#
#
#
# 1.   `Despejar x`
#
# $$
# x=e^{-2x}
# $$
# $$
# x=g(x)
# $$
# 2.   `Proponer un x0`
# $$
# x_0=0.75
# $$
# 3. `x₁:`
#
# `Evaluar la Función g(x) 1 en x0 2`
#
# $$
# g(x_0)=0.2231301601
# $$
# $$
# g(x_0)=x_1
# $$
#
# 4. `x₂,x₃... CON DATOS OBTENIDOS DE *lambda*`
# $$
# g(x_1)=x_2
# $$
# $$
# g(x_2)=x_3
# $$
# $$
# g(x_3)=x_4
# $$
# $$
# g(x_4)=x_5
# $$
#
#
# **Resultado:**
#
# La raíz aproximada es ... con una precisión del orden 10^, hasta la *n* iteración
#
# $$
# |x_n-x_{n-1}|<1x10^{orden}
# $$
#
# \begin{array}{|c|c|c|c|}
# \hline
# Iteraciones&x_i\\
# \hline
# 1&-\\
# \hline
# \end{array}

# %%
#Import Biblioteca math
import numpy as np
import matplotlib.pyplot as plt
import math
import cmath

'EVALUAR FUNCIONES' 

x0=0.75                                          #EDIT x0

#Evaluar función g(x) en x0
F = lambda x: np.exp(-2*x)                       #EDIT g(x)
print('g(x0)=x1=', F(x0))                        

#Evaluar función g(x) en x1
G = lambda x: np.exp(-2*x)                       #EDIT g(x)
print('g(x1)=x2=', G(F(x0)))                      

#Evaluar función g(x) en x2
H = lambda x: np.exp(-2*x)                       #EDIT g(x)
print('g(x2)=x3=', H(G(F(x0))))              

#Evaluar función g(x) en x3
I = lambda x: np.exp(-2*x)                       #EDIT g(x)
print('g(x3)=x4=', I(H(G(F(x0)))))              

#Evaluar función g(x) en x4
J = lambda x: np.exp(-2*x)                       #EDIT g(x)
print('g(x4)=x5=', J(I(H(G(F(x0))))))     

#Evaluar función g(x) en x5
K = lambda x: np.exp(-2*x)                       #EDIT g(x)
print('g(x5)=x6=', K(J(I(H(G(F(x0)))))))     

#Evaluar función g(x) en x6
L = lambda x: np.exp(-2*x)                       #EDIT g(x)
print('g(x6)=x7=', L(K(J(I(H(G(F(x0))))))))    

#Evaluar función g(x) en x7
M = lambda x: np.exp(-2*x)                       #EDIT g(x)
print('g(x7)=x8=', M(L(K(J(I(H(G(F(x0)))))))))    

#Evaluar función g(x) en x8
N = lambda x: np.exp(-2*x)                       #EDIT g(x)
print('g(x8)=x9=', N(M(L(K(J(I(H(G(F(x0)))))))))) 

#Evaluar función g(x) en x9
O = lambda x: np.exp(-2*x)                       #EDIT g(x)
print('g(x9)=x10=', O(N(M(L(K(J(I(H(G(F(x0))))))))))) 

#Evaluar función g(x) en x10
P = lambda x: np.exp(-2*x)                       #EDIT g(x)
print('g(x10)=x11=', P(O(N(M(L(K(J(I(H(G(F(x0)))))))))))) 

#Evaluar función g(x) en x11
Q = lambda x: np.exp(-2*x)                       #EDIT g(x)
print('g(x11)=x12=', Q(P(O(N(M(L(K(J(I(H(G(F(x0))))))))))))) 

#Evaluar función g(x) en x12
R = lambda x: np.exp(-2*x)                       #EDIT g(x)
print('g(x12)=x13=', R(Q(P(O(N(M(L(K(J(I(H(G(F(x0)))))))))))))) 

#Evaluar función g(x) en x13
S = lambda x: np.exp(-2*x)                       #EDIT g(x)
print('g(x13)=x14=', S(R(Q(P(O(N(M(L(K(J(I(H(G(F(x0))))))))))))))) 

#Evaluar función g(x) en x14
T = lambda x: np.exp(-2*x)                       #EDIT g(x)
print('g(x14)=x15=', T(S(R(Q(P(O(N(M(L(K(J(I(H(G(F(x0)))))))))))))))) 

#Evaluar función g(x) en x15
U = lambda x: np.exp(-2*x)                       #EDIT g(x)
print('g(x15)=x16=', U(T(S(R(Q(P(O(N(M(L(K(J(I(H(G(F(x0))))))))))))))))) 

#Evaluar función g(x) en x16
V = lambda x: np.exp(-2*x)                       #EDIT g(x)
print('g(x16)=x17=', V(U(T(S(R(Q(P(O(N(M(L(K(J(I(H(G(F(x0)))))))))))))))))) 

#Evaluar función g(x) en x17
W = lambda x: np.exp(-2*x)                       #EDIT g(x)
print('g(x17)=x18=', W(V(U(T(S(R(Q(P(O(N(M(L(K(J(I(H(G(F(x0))))))))))))))))))) 

#Evaluar función g(x) en x18
X = lambda x: np.exp(-2*x)                       #EDIT g(x)
print('g(x18)=x19=', X(W(V(U(T(S(R(Q(P(O(N(M(L(K(J(I(H(G(F(x0)))))))))))))))))))) 

#Evaluar función g(x) en x19
Y = lambda x: np.exp(-2*x)                       #EDIT g(x)
print('g(x19)=x20=', Y(X(W(V(U(T(S(R(Q(P(O(N(M(L(K(J(I(H(G(F(x0)))))))))))))))))))))
# Out:
# g(x0)=x1= 0.22313016014842982
# g(x1)=x2= 0.6400171409217342
# g(x2)=x3= 0.2780277689853607
# g(x3)=x4= 0.5734666258186054
# g(x4)=x5= 0.3176093051722006
# g(x5)=x6= 0.5298196515999707
# g(x6)=x7= 0.34658079837224354
# g(x7)=x8= 0.4999927919596855
# g(x8)=x9= 0.36788474458935516
# g(x9)=x10= 0.47913662663752576
# g(x10)=x11= 0.38355461616777625
# g(x11)=x12= 0.46435346797589794
# g(x12)=x13= 0.39506422358157506
# g(x13)=x14= 0.45378650394964964
# g(x14)=x15= 0.40350233359768667
# g(x15)=x16= 0.44619256181355177
# g(x16)=x17= 0.40967745515798265
# g(x17)=x18= 0.4407158640833207
# g(x18)=x19= 0.41418948022152374
# g(x19)=x20= 0.4367567126915957

# %% [markdown]
# #5: λ (ej. 3)
#
# Resolver f(x)=0 encontrando una raíz de la función:
# $$
# f(x)=e^{-3x}-5x+2
# $$
#
#
#
# 1.   `Despejar x`
#
# $$
# 5x=e^{-3x}+2
# $$
#
# $$
# x=\frac{e^{-3x}+2}{5}
# $$
# $$
# x=g(x)
# $$
# 2.   `Proponer un x0`
# $$
# x_0=2
# $$
# 3. `x₁:`
#
# `Evaluar la Función g(x) 1 en x0 2`
#
# $$
# g(x_0)=0.40049575043533325
# $$
# $$
# g(x_0)=x_1
# $$
#
# 4. `x₂,x₃... CON DATOS OBTENIDOS DE *lambda*`
# $$
# g(x_1)=x_2
# $$
# $$
# g(x_2)=x_3
# $$
# $$
# g(x_3)=x_4
# $$
# $$
# g(x_4)=x_5
# $$
#
#
# **Resultado:**
#
# La raíz aproximada es ... con una precisión del orden 10^, hasta la *n* iteración
#
# $$
# |x_n-x_{n-1}|<1x10^{orden}
# $$
#
# \begin{array}{|c|c|c|c|}
# \hline
# Iteraciones&x_i\\
# \hline
# 1&-\\
# \hline
# \end{array}

# %%
#Import Biblioteca math
import numpy as np
import matplotlib.pyplot as plt
import math
import cmath

'EVALUAR FUNCIONES' 

x0=2                                             #EDIT x0

#Evaluar función g(x) en x0
F = lambda x: (np.exp(-3*x)+2)/5                 #EDIT g(x)
print('g(x0)=x1=', F(x0))                        

#Evaluar función g(x) en x1
G = lambda x: (np.exp(-3*x)+2)/5                 #EDIT g(x)
print('g(x1)=x2=', G(F(x0)))                      

#Evaluar función g(x) en x2
H = lambda x: (np.exp(-3*x)+2)/5                 #EDIT g(x)
print('g(x2)=x3=', H(G(F(x0))))              

#Evaluar función g(x) en x3
I = lambda x: (np.exp(-3*x)+2)/5                 #EDIT g(x)
print('g(x3)=x4=', I(H(G(F(x0)))))              

#Evaluar función g(x) en x4
J = lambda x: (np.exp(-3*x)+2)/5                 #EDIT g(x)
print('g(x4)=x5=', J(I(H(G(F(x0))))))     

#Evaluar función g(x) en x5
K = lambda x: (np.exp(-3*x)+2)/5                 #EDIT g(x)
print('g(x5)=x6=', K(J(I(H(G(F(x0)))))))     

#Evaluar función g(x) en x6
L = lambda x: (np.exp(-3*x)+2)/5                 #EDIT g(x)
print('g(x6)=x7=', L(K(J(I(H(G(F(x0))))))))    

#Evaluar función g(x) en x7
M = lambda x: (np.exp(-3*x)+2)/5                 #EDIT g(x)
print('g(x7)=x8=', M(L(K(J(I(H(G(F(x0)))))))))    

#Evaluar función g(x) en x8
N = lambda x: (np.exp(-3*x)+2)/5                 #EDIT g(x)
print('g(x8)=x9=', N(M(L(K(J(I(H(G(F(x0)))))))))) 

#Evaluar función g(x) en x9
O = lambda x: (np.exp(-3*x)+2)/5                 #EDIT g(x)
print('g(x9)=x10=', O(N(M(L(K(J(I(H(G(F(x0))))))))))) 

#Evaluar función g(x) en x10
P = lambda x: (np.exp(-3*x)+2)/5                 #EDIT g(x)
print('g(x10)=x11=', P(O(N(M(L(K(J(I(H(G(F(x0)))))))))))) 

#Evaluar función g(x) en x11
Q = lambda x: (np.exp(-3*x)+2)/5                 #EDIT g(x)
print('g(x11)=x12=', Q(P(O(N(M(L(K(J(I(H(G(F(x0))))))))))))) 

#Evaluar función g(x) en x12
R = lambda x: (np.exp(-3*x)+2)/5                 #EDIT g(x)
print('g(x12)=x13=', R(Q(P(O(N(M(L(K(J(I(H(G(F(x0)))))))))))))) 

#Evaluar función g(x) en x13
S = lambda x: (np.exp(-3*x)+2)/5                 #EDIT g(x)
print('g(x13)=x14=', S(R(Q(P(O(N(M(L(K(J(I(H(G(F(x0))))))))))))))) 

#Evaluar función g(x) en x14
T = lambda x: (np.exp(-3*x)+2)/5                 #EDIT g(x)
print('g(x14)=x15=', T(S(R(Q(P(O(N(M(L(K(J(I(H(G(F(x0)))))))))))))))) 

#Evaluar función g(x) en x15
U = lambda x: (np.exp(-3*x)+2)/5                 #EDIT g(x)
print('g(x15)=x16=', U(T(S(R(Q(P(O(N(M(L(K(J(I(H(G(F(x0))))))))))))))))) 

#Evaluar función g(x) en x16
V = lambda x: (np.exp(-3*x)+2)/5                 #EDIT g(x)
print('g(x16)=x17=', V(U(T(S(R(Q(P(O(N(M(L(K(J(I(H(G(F(x0)))))))))))))))))) 

#Evaluar función g(x) en x17
W = lambda x: (np.exp(-3*x)+2)/5                 #EDIT g(x)
print('g(x17)=x18=', W(V(U(T(S(R(Q(P(O(N(M(L(K(J(I(H(G(F(x0))))))))))))))))))) 

#Evaluar función g(x) en x18
X = lambda x: (np.exp(-3*x)+2)/5                 #EDIT g(x)
print('g(x18)=x19=', X(W(V(U(T(S(R(Q(P(O(N(M(L(K(J(I(H(G(F(x0)))))))))))))))))))) 

#Evaluar función g(x) en x19
Y = lambda x: (np.exp(-3*x)+2)/5                 #EDIT g(x)
print('g(x19)=x20=', Y(X(W(V(U(T(S(R(Q(P(O(N(M(L(K(J(I(H(G(F(x0)))))))))))))))))))))
# Out:
# g(x0)=x1= 0.40049575043533325
# g(x1)=x2= 0.4601493186740629
# g(x2)=x3= 0.4502931764339092
# g(x3)=x4= 0.45180247029631043
# g(x4)=x5= 0.45156844506398064
# g(x5)=x6= 0.4516046627282749
# g(x6)=x7= 0.4515990560318205
# g(x7)=x8= 0.45159992393985304
# g(x8)=x9= 0.4515997895880625
# g(x9)=x10= 0.4515998103856392
# g(x10)=x11= 0.4515998071661862
# g(x11)=x12= 0.45159980766455565
# g(x12)=x13= 0.45159980758740836
# g(x13)=x14= 0.4515998075993507
# g(x14)=x15= 0.45159980759750207
# g(x15)=x16= 0.4515998075977882
# g(x16)=x17= 0.45159980759774393
# g(x17)=x18= 0.45159980759775076
# g(x18)=x19= 0.4515998075977497
# g(x19)=x20= 0.45159980759774987
