# %% [markdown]
# <a href="https://colab.research.google.com/github/adriana-rosales/Metodos-Numericos-2021-2/blob/main/Cuad_Gauss_n_ptos_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# `NOTAS:`
#
# $$
# ln(x)⇒log(x)
# $$
# $$
# sen(x)⇒sin(x)⇒np.sin(x)
# $$
#
# $$
# ⇒np.cos(x)
# $$
#
# $$
# \pi⇒np.pi=math.pi
# $$
#
# $$
# e^{x}⇒np.exp(x)
# $$
#
# $$
# raíz(x)⇒np.sqrt(x)
# $$

# %% [markdown]
# # **⇒USAR LISTING 4. ⇒Calcular A MANO: (b-a/2), (a+b/2), E%**

# %% [markdown]
# ![Captura de pantalla 2021-08-09 a la(s) 23.12.47.png](data:image/png;base64,...)

# %% [markdown]
# #1: Libro

# %%
import numpy as np
from scipy.integrate import quadrature,fixed_quad


def cuadraturaN(f,a,b,n):
    w=np.array([[1.,1.],
               [0.55555556,0.88888889,0.55555556],
               [0.3478548,0.6521452,0.6521452,0.3478548],
               [0.2369269,0.4786287,0.5688889,0.4786287,\
                0.2369269],
               [0.1713245,0.3607616,0.4679139,0.4679139,\
                0.3606616,0.1713245]])
    
    z=np.array([[-0.577350269,0.577350269],
                [-0.774596669,0,0.774596669],
                [-0.861136312,-0.339981044,0.339981044,\
                 0.861136312],
                [-0.906179846,-0.538469310,0,0.538469310,\
                 0.906179846],
                [-0.932469514,-0.661209386,-0.238619186,\
                 0.238619186,0.661209386,0.932469514]])
    s=0

    for i in range(n):
        s+=w[n-2][i]*f((b-a)/2*z[n-2][i]+(a+b)/2)
    r=(b-a)/2*s
    return r

# Función a integrar
def f(x):
    return 2.41+0.057195*x-4.3e-6*x**2                    #EDIT f(x)

def main():
    a=300+273.15                                         #limite inferior
    b=600+273.15                                         #limite superior
    n=3                                                  #Número de puntos

#Call to función cuadratura
    area=cuadraturaN(f,a,b,n)
    print('Integral aproximada= ',area)

#Call to función quadrature de scipy
    area=quadrature(f,a,b)
    print('quadrature = ',area)

#Call to función fixed_qud de scipy (Gauss)
    area=fixed_quad(f,a,b,(),n)
    print('fixed_quad = ',area)

if __name__ == "__main__": main()

# RESULTADO: 

# Integral aproximada=12446.894097186478
# Out:
# Integral aproximada=  12446.894097186478
# quadrature =  (12446.894034975, 0.0)
# fixed_quad =  (12446.894034975, None)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   if sys.path[0] == '':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %% [markdown]
# #2: Ordinario A
#
# **Ejercicio 5**

# %%
import numpy as np
from scipy.integrate import quadrature,fixed_quad


def cuadraturaN(f,a,b,n):
    w=np.array([[1.,1.], # COEFICIENTES w
               [0.55555556,0.88888889,0.55555556],         #3 Puntos
               [0.3478548,0.6521452,0.6521452,0.3478548],  #4 Puntos
               [0.2369269,0.4786287,0.5688889,0.4786287,\
                0.2369269],                                #5 Puntos
               [0.1713245,0.3607616,0.4679139,0.4679139,\
                0.3606616,0.1713245]])                     #6 Puntos
    
    z=np.array([[-0.577350269,0.577350269], # ABSCISAS z
                [-0.774596669,0,0.774596669],              #3 Puntos
                [-0.861136312,-0.339981044,0.339981044,\
                 0.861136312],                             #4 Puntos
                [-0.906179846,-0.538469310,0,0.538469310,\
                 0.906179846],                             #5 Puntos
                [-0.932469514,-0.661209386,-0.238619186,\
                 0.238619186,0.661209386,0.932469514]])    #6 Puntos
    s=0

    for i in range(n):
        s+=w[n-2][i]*f((b-a)/2*z[n-2][i]+(a+b)/2)
    r=(b-a)/2*s
    return r

# Función a integrar
def f(x):
    return (x**3)/(x-np.sin(x))                          #EDIT f(x)

def main():
    a=-2                                                 #límite inferior
    b=3                                                  #límite superior
    n=4                                                  #Número de puntos

#Call to función cuadratura
    area=cuadraturaN(f,a,b,n)
    print('Integral aproximada= ',area)

#Call to función quadrature de scipy
    area=quadrature(f,a,b)
    print('quadrature = ',area)

#Call to función fixed_qud de scipy (Gauss)
    area=fixed_quad(f,a,b,(),n)
    print('fixed_quad = ',area)

if __name__ == "__main__": main()

# RESULTADO: 

# Integral aproximada=33.97995505702349
# Out:
# Integral aproximada=  33.97995505702349
# quadrature =  (33.980015569077295, 7.717292049846947e-08)
# fixed_quad =  (33.97995537051534, None)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   if sys.path[0] == '':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %% [markdown]
# #3: Ordinario A **PIMENTEL no usar**
#
# **Ejercicio 5**

# %%
import numpy as np
from scipy.integrate import quadrature,fixed_quad


def cuadraturaN(f,a,b,n):
    w=np.array([[1.,1.], # COEFICIENTES w
               [0.55555556,0.88888889,0.55555556],         #3 Puntos
               [0.3478548,0.6521452,0.6521452,0.3478548],  #4 Puntos
               [0.2369269,0.4786287,0.5688889,0.4786287,\
                0.2369269],                                #5 Puntos
               [0.1713245,0.3607616,0.4679139,0.4679139,\
                0.3606616,0.1713245]])                     #6 Puntos
    
    z=np.array([[-0.577350269,0.577350269], # ABSCISAS z
                [-0.774596669,0,0.774596669],              #3 Puntos
                [-0.861136312,-0.339981044,0.339981044,\
                 0.861136312],                             #4 Puntos
                [-0.906179846,-0.538469310,0,0.538469310,\
                 0.906179846],                             #5 Puntos
                [-0.932469514,-0.661209386,-0.238619186,\
                 0.238619186,0.661209386,0.932469514]])    #6 Puntos
    s=0

    for i in range(n):
        s+=w[n-2][i]*f(z[n-2][i])
    r=s
    return r

# Función a integrar
def f(x):
    return (x**3)/(x-np.sin(x))                          #EDIT f(x)

def main():
    a=-2                                                 #límite inferior
    b=3                                                  #límite superior
    n=4                                                  #Número de puntos

#Call to función cuadratura
    area=cuadraturaN(f,a,b,n)
    print('Integral aproximada= ',area)

#Call to función quadrature de scipy
    area=quadrature(f,a,b)
    print('quadrature = ',area)

#Call to función fixed_qud de scipy (Gauss)
    area=fixed_quad(f,a,b,(),n)
    print('fixed_quad = ',area)

if __name__ == "__main__": main()
# Out:
# Integral aproximada=  12.203181694720683
# quadrature =  (33.980015569077295, 7.717292049846947e-08)
# fixed_quad =  (33.97995537051534, None)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   if sys.path[0] == '':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %% [markdown]
# #4:

# %%
import numpy as np
from scipy.integrate import quadrature,fixed_quad


def cuadraturaN(f,a,b,n):
    w=np.array([[1.,1.], # COEFICIENTES w
               [0.55555556,0.88888889,0.55555556],         #3 Puntos
               [0.3478548,0.6521452,0.6521452,0.3478548],  #4 Puntos
               [0.2369269,0.4786287,0.5688889,0.4786287,\
                0.2369269],                                #5 Puntos
               [0.1713245,0.3607616,0.4679139,0.4679139,\
                0.3606616,0.1713245]])                     #6 Puntos
    
    z=np.array([[-0.577350269,0.577350269], # ABSCISAS z
                [-0.774596669,0,0.774596669],              #3 Puntos
                [-0.861136312,-0.339981044,0.339981044,\
                 0.861136312],                             #4 Puntos
                [-0.906179846,-0.538469310,0,0.538469310,\
                 0.906179846],                             #5 Puntos
                [-0.932469514,-0.661209386,-0.238619186,\
                 0.238619186,0.661209386,0.932469514]])    #6 Puntos
    s=0

    for i in range(n):
        s+=w[n-2][i]*f((b-a)/2*z[n-2][i]+(a+b)/2)
    r=(b-a)/2*s
    return r

# Función a integrar
def f(x):
    return 2.41+0.057195*x-4.3e-6*x**2                     #EDIT f(x)

def main():
    a=300                                                 #límite inferior
    b=600                                                 #límite superior
    n=3                                                   #Número de puntos

#Call to función cuadratura
    area=cuadraturaN(f,a,b,n)
    print('Integral aproximada= ',area)

#Call to función quadrature de scipy
    area=quadrature(f,a,b)
    print('quadrature = ',area)

#Call to función fixed_qud de scipy (Gauss)
    area=fixed_quad(f,a,b,(),n)
    print('fixed_quad = ',area)

if __name__ == "__main__": main()

# RESULTADO: 

# Integral aproximada=8173.425040844133
# Out:
# Integral aproximada=  8173.425040844133
# quadrature =  (8173.424999999999, 0.0)
# fixed_quad =  (8173.424999999999, None)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   if sys.path[0] == '':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %% [markdown]
# #5: **4 puntos**

# %%
import numpy as np
from scipy.integrate import quadrature,fixed_quad


def cuadraturaN(f,a,b,n):
    w=np.array([[1.,1.], # COEFICIENTES w
               [0.55555556,0.88888889,0.55555556],         #3 Puntos
               [0.3478548,0.6521452,0.6521452,0.3478548],  #4 Puntos
               [0.2369269,0.4786287,0.5688889,0.4786287,\
                0.2369269],                                #5 Puntos
               [0.1713245,0.3607616,0.4679139,0.4679139,\
                0.3606616,0.1713245]])                     #6 Puntos
    
    z=np.array([[-0.577350269,0.577350269], # ABSCISAS z
                [-0.774596669,0,0.774596669],              #3 Puntos
                [-0.861136312,-0.339981044,0.339981044,\
                 0.861136312],                             #4 Puntos
                [-0.906179846,-0.538469310,0,0.538469310,\
                 0.906179846],                             #5 Puntos
                [-0.932469514,-0.661209386,-0.238619186,\
                 0.238619186,0.661209386,0.932469514]])    #6 Puntos
    s=0

    for i in range(n):
        s+=w[n-2][i]*f((b-a)/2*z[n-2][i]+(a+b)/2)
    r=(b-a)/2*s
    return r

# Función a integrar
def f(x):
    return (1/np.sqrt(2*np.pi))*np.exp(-x**2/2)                     #EDIT f(x)

def main():
    a=-0.8                                                 #límite inferior
    b=1.5                                                 #límite superior
    n=4                                                   #Número de puntos

#Call to función cuadratura
    area=cuadraturaN(f,a,b,n)
    print('Integral aproximada= ',area)

#Call to función quadrature de scipy
    area=quadrature(f,a,b)
    print('quadrature = ',area)

#Call to función fixed_qud de scipy (Gauss)
    area=fixed_quad(f,a,b,(),n)
    print('fixed_quad = ',area)

if __name__ == "__main__": main()

# RESULTADO: 

# Integral aproximada=0.7213203987431076
# Out:
# Integral aproximada=  0.7213203987431076
# quadrature =  (0.721337400322854, 1.0183873078162264e-08)
# fixed_quad =  (0.7213203877855212, None)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   if sys.path[0] == '':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %% [markdown]
# #6: **4 puntos**

# %%
import numpy as np
from scipy.integrate import quadrature,fixed_quad


def cuadraturaN(f,a,b,n):
    w=np.array([[1.,1.], # COEFICIENTES w
               [0.55555556,0.88888889,0.55555556],         #3 Puntos
               [0.3478548,0.6521452,0.6521452,0.3478548],  #4 Puntos
               [0.2369269,0.4786287,0.5688889,0.4786287,\
                0.2369269],                                #5 Puntos
               [0.1713245,0.3607616,0.4679139,0.4679139,\
                0.3606616,0.1713245]])                     #6 Puntos
    
    z=np.array([[-0.577350269,0.577350269], # ABSCISAS z
                [-0.774596669,0,0.774596669],              #3 Puntos
                [-0.861136312,-0.339981044,0.339981044,\
                 0.861136312],                             #4 Puntos
                [-0.906179846,-0.538469310,0,0.538469310,\
                 0.906179846],                             #5 Puntos
                [-0.932469514,-0.661209386,-0.238619186,\
                 0.238619186,0.661209386,0.932469514]])    #6 Puntos
    s=0

    for i in range(n):
        s+=w[n-2][i]*f((b-a)/2*z[n-2][i]+(a+b)/2)
    r=(b-a)/2*s
    return r

# Función a integrar
def f(x):
    return np.sin(x)*x**2                     #EDIT f(x)

def main():
    a=1                                                 #límite inferior
    b=3                                                 #límite superior
    n=4                                                   #Número de puntos

#Call to función cuadratura
    area=cuadraturaN(f,a,b,n)
    print('Integral aproximada= ',area)

#Call to función quadrature de scipy
    area=quadrature(f,a,b)
    print('quadrature = ',area)

#Call to función fixed_qud de scipy (Gauss)
    area=fixed_quad(f,a,b,(),n)
    print('fixed_quad = ',area)

if __name__ == "__main__": main()

# RESULTADO: 

# Integral aproximada=5.553432743737919
# Out:
# Integral aproximada=  5.553432743737919
# quadrature =  (5.553423249223206, 4.828872413042973e-08)
# fixed_quad =  (5.553432599924631, None)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   if sys.path[0] == '':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
import numpy as np
from scipy.integrate import quadrature,fixed_quad


def cuadraturaN(f,a,b,n):
    w=np.array([[1.,1.], # COEFICIENTES w
               [0.55555556,0.88888889,0.55555556],         #3 Puntos
               [0.3478548,0.6521452,0.6521452,0.3478548],  #4 Puntos
               [0.2369269,0.4786287,0.5688889,0.4786287,\
                0.2369269],                                #5 Puntos
               [0.1713245,0.3607616,0.4679139,0.4679139,\
                0.3606616,0.1713245]])                     #6 Puntos
    
    z=np.array([[-0.577350269,0.577350269], # ABSCISAS z
                [-0.774596669,0,0.774596669],              #3 Puntos
                [-0.861136312,-0.339981044,0.339981044,\
                 0.861136312],                             #4 Puntos
                [-0.906179846,-0.538469310,0,0.538469310,\
                 0.906179846],                             #5 Puntos
                [-0.932469514,-0.661209386,-0.238619186,\
                 0.238619186,0.661209386,0.932469514]])    #6 Puntos
    s=0

    for i in range(n):
        s+=w[n-2][i]*f((b-a)/2*z[n-2][i]+(a+b)/2)
    r=(b-a)/2*s
    return r

# Función a integrar
def f(x):
    return x*np.exp(np.exp(x))                     #EDIT f(x)

def main():
    a=1                                                 #límite inferior
    b=3                                                 #límite superior
    n=3                                                   #Número de puntos

#Call to función cuadratura
    area=cuadraturaN(f,a,b,n)
    print('Integral aproximada= ',area)

#Call to función quadrature de scipy
    area=quadrature(f,a,b)
    print('quadrature = ',area)

#Call to función fixed_qud de scipy (Gauss)
    area=fixed_quad(f,a,b,(),n)
    print('fixed_quad = ',area)

if __name__ == "__main__": main()

# RESULTADO: 

# Integral aproximada=5.553432743737919
# Out:
# Integral aproximada=  14147987.760052567
# quadrature =  (81778944.9444372, 0.474540576338768)
# fixed_quad =  (14147987.702881867, None)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   if sys.path[0] == '':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
